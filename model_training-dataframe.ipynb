# %%
import numpy as np
import lightgbm as lgbm
import pandas as pd

# %%
'''
File paths
'''
import os

folder = os.path.join("/projectnb","cs542sp","netflix_wrw2", "CS542-final-project", "data")

# %%
# %%time

# # read in the full data :0
# reader = pd.read_sas('data/netflix_analysis_dataset.sas7bdat', chunksize=100_000_000)
# data = next(reader)

data = pd.read_sas('data/netflix_analysis_dataset.sas7bdat')

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243642300 entries, 0 to 243642299
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   User_ID                 float64
#  1   Movie_ID                float64
#  2   Year                    float64
#  3   Rated                   float64
#  4   Ratings_for_Movie       float64
#  5   Ratings_for_Movie_2005  float64
#  6   Netflix_Release_Year    float64
#  7   Release_Year            float64
#  8   AVG_Rating_for_Movie    float64
#  9   Ratings_from_User       float64
#  10  Ratings_from_User_2005  float64
#  11  AVG_Rating_from_User    float64
#  12  User_Entry_Year         float64
# dtypes: float64(13)
# memory usage: 23.6 GB
# CPU times: user 7min 5s, sys: 1min 1s, total: 8min 6s
# Wall time: 8min 8s

# %%
data = data.dropna()

for c in data.columns:
    data.loc[:,c] = pd.to_numeric(data.loc[:,c], downcast="unsigned")
    
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243639408 entries, 0 to 243642299
# Data columns (total 13 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   User_ID                 uint32
#  1   Movie_ID                uint16
#  2   Year                    uint16
#  3   Rated                   uint8
#  4   Ratings_for_Movie       uint32
#  5   Ratings_for_Movie_2005  uint32
#  6   Netflix_Release_Year    uint16
#  7   Release_Year            uint16
#  8   AVG_Rating_for_Movie    float64
#  9   Ratings_from_User       uint16
#  10  Ratings_from_User_2005  uint16
#  11  AVG_Rating_from_User    float64
#  12  User_Entry_Year         uint16
# dtypes: float64(2), uint16(7), uint32(3), uint8(1)
# memory usage: 11.6 GB

# %%
X = data.drop(['Rated'], axis=1)
Y = data.loc[:,"Rated"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, y_train, y_valid = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
from lightgbm import Dataset

train_data = Dataset(X_train, label=y_train)

valid_set = Dataset(X_valid, label=y_valid, reference=train_data)

# %%
# %%time
'''
Train the model using the "lgb.train" api for more control.
'''

params = {
    "objective":'binary',
    "num_leaves": 4095,
    "max_depth": 12,
    "learning_rate": 0.1,
#     "bagging_fraction": 0.5,
#     "bagging_freq": 5,
    "metric":"binary_logloss",
    "num_threads":4,
    "boosting": "goss",
}
# goss is faster than gbdt but worse for small data

model = lgbm.train(
    params,
    train_data,
    num_boost_round=1000,
    valid_sets=[valid_set],
    categorical_feature=[0,1],
    early_stopping_rounds = 10,
)
# Out:
# [LightGBM] [Info] Number of positive: 75359793, number of negative: 107369763
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 1.919094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 23469
# [LightGBM] [Info] Number of data points in the train set: 182729556, number of used features: 12
# [LightGBM] [Info] Using GOSS
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.412412 -> initscore=-0.354005
# [LightGBM] [Info] Start training from score -0.354005
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [1]	valid_0's binary_logloss: 0.670084
# Training until validation scores don't improve for 10 rounds
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [2]	valid_0's binary_logloss: 0.663811
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [3]	valid_0's binary_logloss: 0.658608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [4]	valid_0's binary_logloss: 0.654282
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [5]	valid_0's binary_logloss: 0.650567
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [6]	valid_0's binary_logloss: 0.647404
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [7]	valid_0's binary_logloss: 0.644735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [8]	valid_0's binary_logloss: 0.642519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [9]	valid_0's binary_logloss: 0.640468
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [10]	valid_0's binary_logloss: 0.638719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [11]	valid_0's binary_logloss: 0.637387
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [12]	valid_0's binary_logloss: 0.636141
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [13]	valid_0's binary_logloss: 0.635083
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [14]	valid_0's binary_logloss: 0.634259
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [15]	valid_0's binary_logloss: 0.633419
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [16]	valid_0's binary_logloss: 0.632661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [17]	valid_0's binary_logloss: 0.632087
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [18]	valid_0's binary_logloss: 0.631599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [19]	valid_0's binary_logloss: 0.631159
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [20]	valid_0's binary_logloss: 0.630723
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [21]	valid_0's binary_logloss: 0.630328
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [22]	valid_0's binary_logloss: 0.629992
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [23]	valid_0's binary_logloss: 0.629576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [24]	valid_0's binary_logloss: 0.629325
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [25]	valid_0's binary_logloss: 0.629102
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [26]	valid_0's binary_logloss: 0.628848
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [27]	valid_0's binary_logloss: 0.628503
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [28]	valid_0's binary_logloss: 0.628308
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [29]	valid_0's binary_logloss: 0.628109
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [30]	valid_0's binary_logloss: 0.627969
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [31]	valid_0's binary_logloss: 0.627858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [32]	valid_0's binary_logloss: 0.627747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [33]	valid_0's binary_logloss: 0.627617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [34]	valid_0's binary_logloss: 0.62753
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [35]	valid_0's binary_logloss: 0.627428
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [36]	valid_0's binary_logloss: 0.627106
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [37]	valid_0's binary_logloss: 0.627032
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [38]	valid_0's binary_logloss: 0.626813
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [39]	valid_0's binary_logloss: 0.626695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [40]	valid_0's binary_logloss: 0.62663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [41]	valid_0's binary_logloss: 0.626414
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [42]	valid_0's binary_logloss: 0.626377
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [43]	valid_0's binary_logloss: 0.626288
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [44]	valid_0's binary_logloss: 0.626266
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [45]	valid_0's binary_logloss: 0.626223
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [46]	valid_0's binary_logloss: 0.62621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [47]	valid_0's binary_logloss: 0.626121
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [48]	valid_0's binary_logloss: 0.626099
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [49]	valid_0's binary_logloss: 0.62609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [50]	valid_0's binary_logloss: 0.626084
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [51]	valid_0's binary_logloss: 0.62608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [52]	valid_0's binary_logloss: 0.626074
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [53]	valid_0's binary_logloss: 0.626069
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [54]	valid_0's binary_logloss: 0.626065
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [55]	valid_0's binary_logloss: 0.626061
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [56]	valid_0's binary_logloss: 0.626056
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [57]	valid_0's binary_logloss: 0.626049
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [58]	valid_0's binary_logloss: 0.626044
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [59]	valid_0's binary_logloss: 0.626035
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [60]	valid_0's binary_logloss: 0.625993
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [61]	valid_0's binary_logloss: 0.62599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [62]	valid_0's binary_logloss: 0.625987
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [63]	valid_0's binary_logloss: 0.625983
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [64]	valid_0's binary_logloss: 0.625979
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [65]	valid_0's binary_logloss: 0.625976
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [66]	valid_0's binary_logloss: 0.625972
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [67]	valid_0's binary_logloss: 0.625968
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [68]	valid_0's binary_logloss: 0.625964
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [69]	valid_0's binary_logloss: 0.625961
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [70]	valid_0's binary_logloss: 0.625958
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [71]	valid_0's binary_logloss: 0.625954
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [72]	valid_0's binary_logloss: 0.625951
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [73]	valid_0's binary_logloss: 0.625948
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [74]	valid_0's binary_logloss: 0.625945
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [75]	valid_0's binary_logloss: 0.625942
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [76]	valid_0's binary_logloss: 0.625939
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [77]	valid_0's binary_logloss: 0.625937
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [78]	valid_0's binary_logloss: 0.625933
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [79]	valid_0's binary_logloss: 0.62593
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [80]	valid_0's binary_logloss: 0.625927
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [81]	valid_0's binary_logloss: 0.625924
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [82]	valid_0's binary_logloss: 0.625911
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [83]	valid_0's binary_logloss: 0.625908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [84]	valid_0's binary_logloss: 0.625905
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [85]	valid_0's binary_logloss: 0.625902
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [86]	valid_0's binary_logloss: 0.625899
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [87]	valid_0's binary_logloss: 0.625786
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [88]	valid_0's binary_logloss: 0.625783
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [89]	valid_0's binary_logloss: 0.62578
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [90]	valid_0's binary_logloss: 0.625778
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [91]	valid_0's binary_logloss: 0.625775
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [92]	valid_0's binary_logloss: 0.625773
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [93]	valid_0's binary_logloss: 0.62577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [94]	valid_0's binary_logloss: 0.625768
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [95]	valid_0's binary_logloss: 0.625765
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [96]	valid_0's binary_logloss: 0.625752
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [97]	valid_0's binary_logloss: 0.625749
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [98]	valid_0's binary_logloss: 0.625747
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [99]	valid_0's binary_logloss: 0.625743
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [100]	valid_0's binary_logloss: 0.625741
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [101]	valid_0's binary_logloss: 0.625738
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [102]	valid_0's binary_logloss: 0.625735
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [103]	valid_0's binary_logloss: 0.625732
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [104]	valid_0's binary_logloss: 0.625729
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [105]	valid_0's binary_logloss: 0.625727
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [106]	valid_0's binary_logloss: 0.625725
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [107]	valid_0's binary_logloss: 0.625722
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [108]	valid_0's binary_logloss: 0.625719
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [109]	valid_0's binary_logloss: 0.625706
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [110]	valid_0's binary_logloss: 0.625703
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [111]	valid_0's binary_logloss: 0.625701
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [112]	valid_0's binary_logloss: 0.625699
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [113]	valid_0's binary_logloss: 0.625698
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [114]	valid_0's binary_logloss: 0.625696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [115]	valid_0's binary_logloss: 0.625693
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [116]	valid_0's binary_logloss: 0.62569
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [117]	valid_0's binary_logloss: 0.625688
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [118]	valid_0's binary_logloss: 0.625686
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [119]	valid_0's binary_logloss: 0.625684
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [120]	valid_0's binary_logloss: 0.625682
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [121]	valid_0's binary_logloss: 0.625679
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [122]	valid_0's binary_logloss: 0.625677
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [123]	valid_0's binary_logloss: 0.625675
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [124]	valid_0's binary_logloss: 0.625672
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [125]	valid_0's binary_logloss: 0.625671
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [126]	valid_0's binary_logloss: 0.625669
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [127]	valid_0's binary_logloss: 0.625667
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [128]	valid_0's binary_logloss: 0.625665
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [129]	valid_0's binary_logloss: 0.625663
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [130]	valid_0's binary_logloss: 0.625661
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [131]	valid_0's binary_logloss: 0.625659
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [132]	valid_0's binary_logloss: 0.625657
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [133]	valid_0's binary_logloss: 0.625655
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [134]	valid_0's binary_logloss: 0.625653
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [135]	valid_0's binary_logloss: 0.625651
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [136]	valid_0's binary_logloss: 0.625649
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [137]	valid_0's binary_logloss: 0.625647
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [138]	valid_0's binary_logloss: 0.625645
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [139]	valid_0's binary_logloss: 0.625643
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [140]	valid_0's binary_logloss: 0.625641
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [141]	valid_0's binary_logloss: 0.625639
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [142]	valid_0's binary_logloss: 0.625637
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [143]	valid_0's binary_logloss: 0.625635
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [144]	valid_0's binary_logloss: 0.625633
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [145]	valid_0's binary_logloss: 0.625631
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [146]	valid_0's binary_logloss: 0.625629
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [147]	valid_0's binary_logloss: 0.625628
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [148]	valid_0's binary_logloss: 0.625625
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [149]	valid_0's binary_logloss: 0.625623
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [150]	valid_0's binary_logloss: 0.625621
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [151]	valid_0's binary_logloss: 0.62562
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [152]	valid_0's binary_logloss: 0.625618
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [153]	valid_0's binary_logloss: 0.625617
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [154]	valid_0's binary_logloss: 0.625615
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [155]	valid_0's binary_logloss: 0.625613
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [156]	valid_0's binary_logloss: 0.625611
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [157]	valid_0's binary_logloss: 0.625609
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [158]	valid_0's binary_logloss: 0.625608
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [159]	valid_0's binary_logloss: 0.625606
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [160]	valid_0's binary_logloss: 0.625605
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [161]	valid_0's binary_logloss: 0.625602
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [162]	valid_0's binary_logloss: 0.6256
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [163]	valid_0's binary_logloss: 0.625599
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [164]	valid_0's binary_logloss: 0.625597
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [165]	valid_0's binary_logloss: 0.625595
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [166]	valid_0's binary_logloss: 0.625594
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [167]	valid_0's binary_logloss: 0.625591
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [168]	valid_0's binary_logloss: 0.62559
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [169]	valid_0's binary_logloss: 0.625588
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [170]	valid_0's binary_logloss: 0.625586
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [171]	valid_0's binary_logloss: 0.625584
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [172]	valid_0's binary_logloss: 0.625582
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [173]	valid_0's binary_logloss: 0.62558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [174]	valid_0's binary_logloss: 0.625579
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [175]	valid_0's binary_logloss: 0.625577
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [176]	valid_0's binary_logloss: 0.625575
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [177]	valid_0's binary_logloss: 0.625573
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [178]	valid_0's binary_logloss: 0.625571
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [179]	valid_0's binary_logloss: 0.62557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [180]	valid_0's binary_logloss: 0.625568
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [181]	valid_0's binary_logloss: 0.625566
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [182]	valid_0's binary_logloss: 0.625565
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [183]	valid_0's binary_logloss: 0.625563
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [184]	valid_0's binary_logloss: 0.625561
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [185]	valid_0's binary_logloss: 0.62556
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [186]	valid_0's binary_logloss: 0.625558
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [187]	valid_0's binary_logloss: 0.625557
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [188]	valid_0's binary_logloss: 0.625555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [189]	valid_0's binary_logloss: 0.625553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [190]	valid_0's binary_logloss: 0.625551
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [191]	valid_0's binary_logloss: 0.62555
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [192]	valid_0's binary_logloss: 0.625548
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [193]	valid_0's binary_logloss: 0.625546
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [194]	valid_0's binary_logloss: 0.625545
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [195]	valid_0's binary_logloss: 0.625543
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [196]	valid_0's binary_logloss: 0.625542
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [197]	valid_0's binary_logloss: 0.62554
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [198]	valid_0's binary_logloss: 0.625539
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [199]	valid_0's binary_logloss: 0.625537
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [200]	valid_0's binary_logloss: 0.625536
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [201]	valid_0's binary_logloss: 0.625534
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [202]	valid_0's binary_logloss: 0.625533
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [203]	valid_0's binary_logloss: 0.625532
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [204]	valid_0's binary_logloss: 0.62553
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [205]	valid_0's binary_logloss: 0.625529
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [206]	valid_0's binary_logloss: 0.625528
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [207]	valid_0's binary_logloss: 0.625527
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [208]	valid_0's binary_logloss: 0.625525
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [209]	valid_0's binary_logloss: 0.625524
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [210]	valid_0's binary_logloss: 0.625523
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [211]	valid_0's binary_logloss: 0.625522
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [212]	valid_0's binary_logloss: 0.625521
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [213]	valid_0's binary_logloss: 0.625519
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [214]	valid_0's binary_logloss: 0.625518
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [215]	valid_0's binary_logloss: 0.625516
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [216]	valid_0's binary_logloss: 0.625515

# %%
model.feature_importance()
# Out:
# array([3724, 2008,  837, 2989, 2285,  895, 2474, 3171, 2685, 2124, 1999,
#         691], dtype=int32)

# %%
train_prediction = model.predict(X_train)

# %%
valid_prediction = model.predict(X_valid)

# %%
from sklearn.metrics import accuracy_score

'''
Check for overfitting
'''
print("Overfit check:")
print('Train score:\t{:.3f}'.format(accuracy_score(y_train, train_prediction > 0.5)))
print('Test score:\t{:.3f}'.format(accuracy_score(y_valid, valid_prediction > 0.5)))
# Out:
# Overfit check:
# Train score:	0.655
# Test score:	0.649

# %%
'''
Metrics output
'''
from sklearn.metrics import classification_report
print(classification_report(y_valid, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      0.83      0.73   2944556
#            1       0.59      0.36      0.45   2055379
#
#     accuracy                           0.63   4999935
#    macro avg       0.62      0.59      0.59   4999935
# weighted avg       0.62      0.63      0.61   4999935

# %%
model.save_model('models/20M_test.txt')
